# %%
import pandas as pd
import seaborn as sns
import redis

# %%
### This is just written for testing purposes, it is not meant to be used in production.

# %%
## import data from the SQL SERVER for testing purpose.
